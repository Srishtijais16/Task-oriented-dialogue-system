# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-2b-it")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2-2b-it")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
def generate_response(prompt, max_length=500):
    # Tokenize the input text with padding
    inputs = tokenizer(prompt, return_tensors="pt", padding=True).to(device)

    # Get input_ids and attention_mask
    input_ids = inputs["input_ids"]
    attention_mask = inputs["attention_mask"]

    # Generate a response using the model
    output = model.generate(
        input_ids=input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        num_return_sequences=1,
        pad_token_id=tokenizer.eos_token_id,
        do_sample=False,
    )
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    return response

# %%
def chatbot():
    print("Chatbot is ready! Type 'exit' to stop the chat.")

    while True:

        user_input = input("User: ")

        # Exit condition
        if user_input.lower() == 'exit':
            print("Chatbot: Goodbye!")
            break


        response = generate_response(user_input)
        print(f"Chatbot: {response}")


chatbot()
# Out:
# Chatbot is ready! Type 'exit' to stop the chat.
# User: tell me about nlp?
# Chatbot: tell me about nlp?
#
# ## What is NLP?
#
# Natural Language Processing (NLP) is a branch of Artificial Intelligence (AI) that focuses on enabling computers to understand, interpret, and generate human language.
#
# **Think of it as teaching computers to "speak" and "understand" the way humans do.**
#
# ### Key Concepts:
#
# * **Understanding Language:** NLP involves analyzing text and speech to extract meaning, identify entities, and understand relationships between words and concepts.
# * **Generating Language:** NLP allows computers to create human-like text, translate languages, summarize information, and even write creative content.
# * **Machine Learning:**  NLP heavily relies on machine learning algorithms to learn patterns and relationships in language data.
#
# ### Applications of NLP:
#
# NLP has a wide range of applications across various industries:
#
# * **Chatbots and Virtual Assistants:**  Providing conversational experiences and answering user queries.
# * **Search Engines:** Understanding search queries and providing relevant results.
# * **Sentiment Analysis:**  Analyzing text to understand the emotional tone and opinions expressed.
# * **Machine Translation:**  Translating text from one language to another.
# * **Text Summarization:**  Creating concise summaries of lengthy documents.
# * **Spam Filtering:**  Identifying and filtering unwanted emails.
# * **Medical Diagnosis:**  Analyzing patient records to assist in diagnosis.
# * **Financial Analysis:**  Understanding financial reports and market trends.
# * **Customer Service:**  Automating customer interactions and providing support.
#
#
# ### How NLP Works:
#
# NLP systems typically use a combination of techniques, including:
#
# * **Tokenization:** Breaking down text into individual words or phrases.
# * **Part-of-Speech Tagging:** Identifying the grammatical role of each word.
# * **Named Entity Recognition:** Identifying and classifying named entities like people, organizations, and locations.
# * **Sentiment Analysis:** Determining the emotional tone of text.
# * **Machine Learning:** Training models on large datasets of text to learn language patterns.
#
#
# ### The Future of NLP:
#
# NLP is a rapidly evolving field with exciting advancements on the horizon:
#
# * **More Human-like Language Generation:**  Creating more natural and engaging text.
# * **Multimodal Understanding:**  Combining text with other modalities like images and audio.
# * **Personalized NLP:**  Tailoring NLP systems to individual users and their needs.
# * **Ethical Considerations:**  Addressing potential biases and ethical implications of NLP systems.
# User: tell me about data science?
# Chatbot: tell me about data science?
#
# Data science is a multidisciplinary field that uses scientific methods, processes, algorithms, and systems to extract knowledge and insights from structured and unstructured data.
#
# Here's a breakdown of what that means:
#
# **1. Multidisciplinary:** Data science draws on expertise from various fields, including:
#     * **Statistics:** For analyzing data and drawing conclusions.
#     * **Computer Science:** For developing algorithms and software tools.
#     * **Domain Expertise:** For understanding the context and meaning of the data.
#     * **Mathematics:** For developing mathematical models and theories.
#
# **2. Scientific Methods:** Data scientists use a systematic approach to problem-solving, including:
#     * **Data Collection:** Gathering relevant data from various sources.
#     * **Data Cleaning:** Preparing data for analysis by removing errors and inconsistencies.
#     * **Data Exploration:** Understanding the data through visualization and summary statistics.
#     * **Model Building:** Developing predictive or descriptive models using statistical and machine learning techniques.
#     * **Model Evaluation:** Assessing the performance of models and making adjustments as needed.
#
# **3. Algorithms and Systems:** Data scientists utilize a wide range of algorithms and systems to:
#     * **Analyze data:** Identify patterns, trends, and anomalies.
#     * **Predict future outcomes:** Forecast future events based on historical data.
#     * **Automate tasks:** Streamline data processing and analysis.
#
# **4. Extracting Knowledge and Insights:** The ultimate goal of data science is to:
#     * **Gain a deeper understanding of the data:** Identify key trends and relationships.
#     * **Make informed decisions:** Use insights to improve business processes, products, and services.
#     * **Solve complex problems:** Develop solutions to real-world challenges.
#
# **Applications of Data Science:**
#
# Data science has a wide range of applications across various industries, including:
#
# * **Business:** Customer segmentation, fraud detection, marketing optimization, sales forecasting.
# * **Healthcare:** Disease prediction, personalized medicine, drug discovery, patient monitoring.
# * **Finance:** Risk management, fraud detection, algorithmic trading, investment analysis.
# * **Technology:** Recommender systems, natural language processing, computer vision, machine learning.
# * **Government:** Public policy analysis, crime prediction, resource allocation, disaster response.
#
# **Skills Required for Data Science:**
#
# * **Programming:** Python, R, SQL
# * **Statistics and
# User: exit
# Chatbot: Goodbye!
